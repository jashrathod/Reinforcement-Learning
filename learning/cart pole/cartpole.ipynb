# %%
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam


from scores.score_logger import ScoreLogger

ENV_NAME = "CartPole-v1"

GAMMA = 0.95
LEARNING_RATE = 0.001

MEMORY_SIZE = 1000000
BATCH_SIZE = 20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995


class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)


def cartpole():
    env = gym.make(ENV_NAME)
    score_logger = ScoreLogger(ENV_NAME)
    observation_space = env.observation_space.shape[0]
    action_space = env.action_space.n
    dqn_solver = DQNSolver(observation_space, action_space)
    run = 0
    while True:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        while True:
            step += 1
            #env.render()
            action = dqn_solver.act(state)
            state_next, reward, terminal, info = env.step(action)
            reward = reward if not terminal else -reward
            state_next = np.reshape(state_next, [1, observation_space])
            dqn_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal:
                print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
                score_logger.add_score(step, run)
                break
            dqn_solver.experience_replay()


if __name__ == "__main__":
    cartpole()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1226 15:56:56.644364 4569554240 deprecation_wrapper.py:119] From /Users/jashrathod/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1226 15:56:56.666205 4569554240 deprecation_wrapper.py:119] From /Users/jashrathod/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1226 15:56:56.688163 4569554240 deprecation_wrapper.py:119] From /Users/jashrathod/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1226 15:56:56.746692 4569554240 deprecation_wrapper.py:119] From /Users/jashrathod/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1226 15:56:56.773185 4569554240 deprecation_wrapper.py:119] From /Users/jashrathod/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1226 15:56:56.777379 4569554240 deprecation_wrapper.py:119] From /Users/jashrathod/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
# Run: 1, exploration: 0.9369146928798039, score: 33
# Scores: (min: 33, avg: 33, max: 33)
#
# Run: 2, exploration: 0.8955869907338783, score: 10
# /Users/jashrathod/PycharmProjects/Reinforcement-Learning/cartpole/scores/score_logger.py:77: RankWarning: Polyfit may be poorly conditioned
#   z = np.polyfit(np.array(trend_x), np.array(y[1:]), 1)
# Scores: (min: 10, avg: 21.5, max: 33)
#
# Run: 3, exploration: 0.8390886103705794, score: 14
# Scores: (min: 10, avg: 19, max: 33)
#
# Run: 4, exploration: 0.7552531090661897, score: 22
# Scores: (min: 10, avg: 19.75, max: 33)
#
# Run: 5, exploration: 0.6935613678313175, score: 18
# Scores: (min: 10, avg: 19.4, max: 33)
#
# Run: 6, exploration: 0.5647174463480732, score: 42
# Scores: (min: 10, avg: 23.166666666666668, max: 42)
#
# Run: 7, exploration: 0.531750826943791, score: 13
# Scores: (min: 10, avg: 21.714285714285715, max: 42)
#
# Run: 8, exploration: 0.5082950737585841, score: 10
# Scores: (min: 10, avg: 20.25, max: 42)
#
# Run: 9, exploration: 0.4858739637363176, score: 10
# Scores: (min: 10, avg: 19.11111111111111, max: 42)
#
# Run: 10, exploration: 0.4598090507939749, score: 12
# Scores: (min: 10, avg: 18.4, max: 42)
#
# Run: 11, exploration: 0.3403786882983606, score: 61
# Scores: (min: 10, avg: 22.272727272727273, max: 61)
#
# Run: 12, exploration: 0.30945741577570285, score: 20
# Scores: (min: 10, avg: 22.083333333333332, max: 61)
#
# Run: 13, exploration: 0.27714603575484437, score: 23
# Scores: (min: 10, avg: 22.153846153846153, max: 61)
#
# Run: 14, exploration: 0.24450384299593592, score: 26
# Scores: (min: 10, avg: 22.428571428571427, max: 61)
#
# Run: 15, exploration: 0.2290792429684691, score: 14
# Scores: (min: 10, avg: 21.866666666666667, max: 61)
#
# Run: 16, exploration: 0.20826882814336947, score: 20
# Scores: (min: 10, avg: 21.75, max: 61)
#
# Run: 17, exploration: 0.192217783647157, score: 17
# Scores: (min: 10, avg: 21.470588235294116, max: 61)
#
# Run: 18, exploration: 0.17043057265153258, score: 25
# Scores: (min: 10, avg: 21.666666666666668, max: 61)
#
# Run: 19, exploration: 0.1557266555690826, score: 19
# Scores: (min: 10, avg: 21.526315789473685, max: 61)
#
# Run: 20, exploration: 0.13807558583895513, score: 25
# Scores: (min: 10, avg: 21.7, max: 61)
#
# Run: 21, exploration: 0.1063939893092943, score: 53
# Scores: (min: 10, avg: 23.19047619047619, max: 61)
#
# Run: 22, exploration: 0.09528507271768329, score: 23
# Scores: (min: 10, avg: 23.181818181818183, max: 61)
#
# Run: 23, exploration: 0.08662902049662846, score: 20
# Scores: (min: 10, avg: 23.043478260869566, max: 61)
#
# Run: 24, exploration: 0.07836551983717477, score: 21
# Scores: (min: 10, avg: 22.958333333333332, max: 61)
#
# Run: 25, exploration: 0.07342180695061275, score: 14
# Scores: (min: 10, avg: 22.6, max: 61)
#
# Run: 26, exploration: 0.06285510723190912, score: 32
# Scores: (min: 10, avg: 22.96153846153846, max: 61)
#
# Run: 27, exploration: 0.05601075525639029, score: 24
# Scores: (min: 10, avg: 23, max: 61)
#
# Run: 28, exploration: 0.04146257532741124, score: 61
# Scores: (min: 10, avg: 24.357142857142858, max: 61)
#
# Run: 29, exploration: 0.031158165231288826, score: 58
# Scores: (min: 10, avg: 25.517241379310345, max: 61)
#
# Run: 30, exploration: 0.025116802354115567, score: 44
# Scores: (min: 10, avg: 26.133333333333333, max: 61)
#
# Run: 31, exploration: 0.020348562734319765, score: 43
# Scores: (min: 10, avg: 26.677419354838708, max: 61)
#
# Run: 32, exploration: 0.015997113097568336, score: 49
# Scores: (min: 10, avg: 27.375, max: 61)
#
# Run: 33, exploration: 0.014398800381387675, score: 22
# Scores: (min: 10, avg: 27.21212121212121, max: 61)
#
# Run: 34, exploration: 0.01, score: 74
# Scores: (min: 10, avg: 28.58823529411765, max: 74)
#
# Run: 35, exploration: 0.01, score: 64
# Scores: (min: 10, avg: 29.6, max: 74)
#
# Run: 36, exploration: 0.01, score: 48
# Scores: (min: 10, avg: 30.11111111111111, max: 74)
#
# Run: 37, exploration: 0.01, score: 48
# Scores: (min: 10, avg: 30.594594594594593, max: 74)
#
# Run: 38, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 31.86842105263158, max: 79)
#
# Run: 39, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 33.41025641025641, max: 92)
#
# Run: 40, exploration: 0.01, score: 74
# Scores: (min: 10, avg: 34.425, max: 92)
#
# Run: 41, exploration: 0.01, score: 66
# Scores: (min: 10, avg: 35.19512195121951, max: 92)
#
# Run: 42, exploration: 0.01, score: 50
# Scores: (min: 10, avg: 35.54761904761905, max: 92)
#
# Run: 43, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 35.906976744186046, max: 92)
#
# Run: 44, exploration: 0.01, score: 44
# Scores: (min: 10, avg: 36.09090909090909, max: 92)
#
# Run: 45, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 35.888888888888886, max: 92)
#
# Run: 46, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 35.78260869565217, max: 92)
#
# Run: 47, exploration: 0.01, score: 46
# Scores: (min: 10, avg: 36, max: 92)
#
# Run: 48, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 36.020833333333336, max: 92)
#
# Run: 49, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 35.95918367346939, max: 92)
#
# Run: 50, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 36.28, max: 92)
#
# Run: 51, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 37.90196078431372, max: 119)
#
# Run: 52, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 40, max: 147)
#
# Run: 53, exploration: 0.01, score: 85
# Scores: (min: 10, avg: 40.84905660377358, max: 147)
#
# Run: 54, exploration: 0.01, score: 126
# Scores: (min: 10, avg: 42.425925925925924, max: 147)
#
# Run: 55, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 43.32727272727273, max: 147)
#
# Run: 56, exploration: 0.01, score: 246
# Scores: (min: 10, avg: 46.94642857142857, max: 246)
#
# Run: 57, exploration: 0.01, score: 257
# Scores: (min: 10, avg: 50.63157894736842, max: 257)
#
# Run: 58, exploration: 0.01, score: 315
# Scores: (min: 10, avg: 55.189655172413794, max: 315)
#
# Run: 59, exploration: 0.01, score: 322
# Scores: (min: 10, avg: 59.71186440677966, max: 322)
#
# Run: 60, exploration: 0.01, score: 194
# Scores: (min: 10, avg: 61.95, max: 322)
#
# Run: 61, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 64.31147540983606, max: 322)
#
# Run: 62, exploration: 0.01, score: 188
# Scores: (min: 10, avg: 66.30645161290323, max: 322)
#
# Run: 63, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 67.68253968253968, max: 322)
#
# Run: 64, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 69.59375, max: 322)
#
# Run: 65, exploration: 0.01, score: 202
# Scores: (min: 10, avg: 71.63076923076923, max: 322)
#
# Run: 66, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 73.06060606060606, max: 322)
#
# Run: 67, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 74.02985074626865, max: 322)
#
# Run: 68, exploration: 0.01, score: 240
# Scores: (min: 10, avg: 76.47058823529412, max: 322)
#
# Run: 69, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 78.4927536231884, max: 322)
#
# Run: 70, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 79.74285714285715, max: 322)
#
# Run: 71, exploration: 0.01, score: 269
# Scores: (min: 10, avg: 82.40845070422536, max: 322)
#
# Run: 72, exploration: 0.01, score: 169
# Scores: (min: 10, avg: 83.61111111111111, max: 322)
#
# Run: 73, exploration: 0.01, score: 178
# Scores: (min: 10, avg: 84.9041095890411, max: 322)
#
# Run: 74, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 86.54054054054055, max: 322)
#
# Run: 75, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 88.17333333333333, max: 322)
#
# Run: 76, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 89.42105263157895, max: 322)
#
# Run: 77, exploration: 0.01, score: 204
# Scores: (min: 10, avg: 90.9090909090909, max: 322)
#
# Run: 78, exploration: 0.01, score: 223
# Scores: (min: 10, avg: 92.6025641025641, max: 322)
#
# Run: 79, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 93.41772151898734, max: 322)
#
# Run: 80, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 94.8875, max: 322)
#
# Run: 81, exploration: 0.01, score: 205
# Scores: (min: 10, avg: 96.24691358024691, max: 322)
#
# Run: 82, exploration: 0.01, score: 243
# Scores: (min: 10, avg: 98.03658536585365, max: 322)
#
# Run: 83, exploration: 0.01, score: 219
# Scores: (min: 10, avg: 99.49397590361446, max: 322)
#
# Run: 84, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 100.80952380952381, max: 322)
#
# Run: 85, exploration: 0.01, score: 212
# Scores: (min: 10, avg: 102.11764705882354, max: 322)
#
# Run: 86, exploration: 0.01, score: 239
# Scores: (min: 10, avg: 103.70930232558139, max: 322)
#
# Run: 87, exploration: 0.01, score: 207
# Scores: (min: 10, avg: 104.89655172413794, max: 322)
#
# Run: 88, exploration: 0.01, score: 263
# Scores: (min: 10, avg: 106.69318181818181, max: 322)
#
# Run: 89, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 107.2247191011236, max: 322)
#
# Run: 90, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 108.43333333333334, max: 322)
# Run: 91, exploration: 0.01, score: 231
# Scores: (min: 10, avg: 109.78021978021978, max: 322)
#
# Run: 92, exploration: 0.01, score: 219
# Scores: (min: 10, avg: 110.96739130434783, max: 322)
#
# Run: 93, exploration: 0.01, score: 256
# Scores: (min: 10, avg: 112.52688172043011, max: 322)
#
# Run: 94, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 113.37234042553192, max: 322)
#
# Run: 95, exploration: 0.01, score: 246
# Scores: (min: 10, avg: 114.76842105263158, max: 322)
#
# Run: 96, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 115.64583333333333, max: 322)
#
# Run: 97, exploration: 0.01, score: 344
# Scores: (min: 10, avg: 118, max: 344)
#
# Run: 98, exploration: 0.01, score: 258
# Scores: (min: 10, avg: 119.42857142857143, max: 344)
#
# Run: 99, exploration: 0.01, score: 214
# Scores: (min: 10, avg: 120.38383838383838, max: 344)
#
# Run: 100, exploration: 0.01, score: 201
# Scores: (min: 10, avg: 121.19, max: 344)
#
# Run: 101, exploration: 0.01, score: 287
# Scores: (min: 10, avg: 123.73, max: 344)
#
# Run: 102, exploration: 0.01, score: 293
# Scores: (min: 10, avg: 126.56, max: 344)
#
# Run: 103, exploration: 0.01, score: 319
# Scores: (min: 10, avg: 129.61, max: 344)
#
# Run: 104, exploration: 0.01, score: 197
# Scores: (min: 10, avg: 131.36, max: 344)
#
# Run: 105, exploration: 0.01, score: 384
# Scores: (min: 10, avg: 135.02, max: 384)
#
# Run: 106, exploration: 0.01, score: 230
# Scores: (min: 10, avg: 136.9, max: 384)
#
# Run: 107, exploration: 0.01, score: 222
# Scores: (min: 10, avg: 138.99, max: 384)
#
# Run: 108, exploration: 0.01, score: 372
# Scores: (min: 10, avg: 142.61, max: 384)
#
# Run: 109, exploration: 0.01, score: 175
# Scores: (min: 12, avg: 144.26, max: 384)
#
# Run: 110, exploration: 0.01, score: 318
# Scores: (min: 14, avg: 147.32, max: 384)
#
# Run: 111, exploration: 0.01, score: 244
# Scores: (min: 14, avg: 149.15, max: 384)
#
# Run: 112, exploration: 0.01, score: 261
# Scores: (min: 14, avg: 151.56, max: 384)
#
# Run: 113, exploration: 0.01, score: 258
# Scores: (min: 14, avg: 153.91, max: 384)
#
# Run: 114, exploration: 0.01, score: 232
# Scores: (min: 14, avg: 155.97, max: 384)
#
# Run: 115, exploration: 0.01, score: 404
# Scores: (min: 14, avg: 159.87, max: 404)
#
# Run: 116, exploration: 0.01, score: 232
# Scores: (min: 14, avg: 161.99, max: 404)
#
# Run: 117, exploration: 0.01, score: 107
# Scores: (min: 14, avg: 162.89, max: 404)
#
# Run: 118, exploration: 0.01, score: 279
# Scores: (min: 14, avg: 165.43, max: 404)
#
# Run: 119, exploration: 0.01, score: 350
# Scores: (min: 14, avg: 168.74, max: 404)
#
# Run: 120, exploration: 0.01, score: 288
# Scores: (min: 14, avg: 171.37, max: 404)
#
# Run: 121, exploration: 0.01, score: 319
# Scores: (min: 14, avg: 174.03, max: 404)
#
# Run: 122, exploration: 0.01, score: 205
# Scores: (min: 14, avg: 175.85, max: 404)
#
# Run: 123, exploration: 0.01, score: 234
# Scores: (min: 14, avg: 177.99, max: 404)
#
# Run: 124, exploration: 0.01, score: 364
# Scores: (min: 14, avg: 181.42, max: 404)
#
# Run: 125, exploration: 0.01, score: 161
# Scores: (min: 22, avg: 182.89, max: 404)
#
# Run: 126, exploration: 0.01, score: 262
# Scores: (min: 22, avg: 185.19, max: 404)
#
# Run: 127, exploration: 0.01, score: 260
# Scores: (min: 22, avg: 187.55, max: 404)
#
# Run: 128, exploration: 0.01, score: 242
# Scores: (min: 22, avg: 189.36, max: 404)
#
# Run: 129, exploration: 0.01, score: 205
# Scores: (min: 22, avg: 190.83, max: 404)
#
# Run: 130, exploration: 0.01, score: 184
# Scores: (min: 22, avg: 192.23, max: 404)
#
# Run: 131, exploration: 0.01, score: 211
# Scores: (min: 22, avg: 193.91, max: 404)
#
# Run: 132, exploration: 0.01, score: 427
# Scores: (min: 22, avg: 197.69, max: 427)
#
# Solved in 32 runs, 132 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d01f3183bf92> in <module>
#      90
#      91 if __name__ == "__main__":
# ---> 92     cartpole()
#
# <ipython-input-3-d01f3183bf92> in cartpole()
#      84             if terminal:
#      85                 print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# ~/PycharmProjects/Reinforcement-Learning/cartpole/scores/score_logger.py in add_score(self, score, run)
#      52                            show_trend=False,
#      53                            show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined
